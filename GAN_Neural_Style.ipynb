# %% [markdown]
# <a href="https://colab.research.google.com/github/rdharini2001/Curl2021/blob/main/GAN_Neural_Style.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If you are running in colab, select tensorflow version 1.x:

# %%
# %tensorflow_version 1.x

# %% [markdown]
# Or, if running locally, you need tensorflow version below 2

# %%
#!pip install -q 'tensorflow-gpu<2'

# %%
# !pip install -q 'scipy<=1.2.1'  # scipy.misc.imread is deprecated in later versions

# %%
# !git clone https://github.com/titu1994/Neural-Style-Transfer.git
# Out:
# fatal: destination path 'Neural-Style-Transfer' already exists and is not an empty directory.

# %%
dir_path = "Neural-Style-Transfer"

# %% [markdown]
# # Network Type
#
# Choose the network type below :
#
# - "Network" for the original style transfer
# - "INetwork" for the improved style transfer (default)

# %%
NETWORK = 'INetwork' + '.py'

# %%
# List all the arguments that can be supplied to Network.py
# !python {dir_path}/{NETWORK} -h
# Out:
# Using TensorFlow backend.
# usage: INetwork.py [-h] [--style_masks STYLE_MASKS [STYLE_MASKS ...]]
#                    [--content_mask CONTENT_MASK] [--color_mask COLOR_MASK]
#                    [--image_size IMG_SIZE] [--content_weight CONTENT_WEIGHT]
#                    [--style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]]
#                    [--style_scale STYLE_SCALE]
#                    [--total_variation_weight TV_WEIGHT] [--num_iter NUM_ITER]
#                    [--model MODEL] [--content_loss_type CONTENT_LOSS_TYPE]
#                    [--rescale_image RESCALE_IMAGE]
#                    [--rescale_method RESCALE_METHOD]
#                    [--maintain_aspect_ratio MAINTAIN_ASPECT_RATIO]
#                    [--content_layer CONTENT_LAYER] [--init_image INIT_IMAGE]
#                    [--pool_type POOL] [--preserve_color COLOR]
#                    [--min_improvement MIN_IMPROVEMENT]
#                    base ref [ref ...] res_prefix
#
# Neural style transfer with Keras.
#
# positional arguments:
#   base                  Path to the image to transform.
#   ref                   Path to the style reference image.
#   res_prefix            Prefix for the saved results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --style_masks STYLE_MASKS [STYLE_MASKS ...]
#                         Masks for style images
#   --content_mask CONTENT_MASK
#                         Masks for the content image
#   --color_mask COLOR_MASK
#                         Mask for color preservation
#   --image_size IMG_SIZE
#                         Minimum image size
#   --content_weight CONTENT_WEIGHT
#                         Weight of content
#   --style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]
#                         Weight of style, can be multiple for multiple styles
#   --style_scale STYLE_SCALE
#                         Scale the weighing of the style
#   --total_variation_weight TV_WEIGHT
#                         Total Variation weight
#   --num_iter NUM_ITER   Number of iterations
#   --model MODEL         Choices are 'vgg16' and 'vgg19'
#   --content_loss_type CONTENT_LOSS_TYPE
#                         Can be one of 0, 1 or 2. Readme contains the required
#                         information of each mode.
#   --rescale_image RESCALE_IMAGE
#                         Rescale image after execution to original dimentions
#   --rescale_method RESCALE_METHOD
#                         Rescale image algorithm
#   --maintain_aspect_ratio MAINTAIN_ASPECT_RATIO
#                         Maintain aspect ratio of loaded images
#   --content_layer CONTENT_LAYER
#                         Content layer used for content loss.
#   --init_image INIT_IMAGE
#                         Initial image used to generate the final image.
#                         Options are 'content', 'noise', or 'gray'
#   --pool_type POOL      Pooling type. Can be "ave" for average pooling or
#                         "max" for max pooling
#   --preserve_color COLOR
#                         Preserve original color in image
#   --min_improvement MIN_IMPROVEMENT
#                         Defines minimum improvement required to continue
#                         script

# %% [markdown]
# # Network Parameters
#
# Here, we will setup all of the parameters for the `Network.py` script.

# %%
# Image size
IMAGE_SIZE = 500

# Loss Weights
CONTENT_WEIGHT = 0.025
STYLE_WEIGHT = 1.0
STYLE_SCALE = 1.0
TOTAL_VARIATION_WEIGHT = 8.5e-5
CONTENT_LOSS_TYPE = 0

# Training arguments
NUM_ITERATIONS = 50
MODEL = 'vgg19'
RESCALE_IMAGE = 'false'
MAINTAIN_ASPECT_RATIO = 'false'  # Set to false if OOM occurs

# Transfer Arguments
CONTENT_LAYER = 'conv' + '5_2'  # only change the number 5_2 to something in a similar format
INITIALIZATION_IMAGE = 'content'
POOLING_TYPE = 'max'

# Extra arguments
PRESERVE_COLOR = 'false'
MIN_IMPROVEMENT = 0.0

# %% [markdown]
# # Content Image
#
# Run the below cell to upload the Content Image. Make sure to select **just 1 image**

# %%
from google.colab import files

content_img = files.upload()
# Out:
#      <input type="file" id="files-883207af-26ea-446f-9d3d-7df216082833" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-883207af-26ea-446f-9d3d-7df216082833">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nature.jpg to nature (2).jpg

# %%
import os

CONTENT_IMAGE_FN = list(content_img)[0]
CONTENT_IMAGE_FN_temp = CONTENT_IMAGE_FN.strip().replace(" ", "_")

if CONTENT_IMAGE_FN != CONTENT_IMAGE_FN_temp:
  os.rename(CONTENT_IMAGE_FN, CONTENT_IMAGE_FN_temp)
  CONTENT_IMAGE_FN = CONTENT_IMAGE_FN_temp
  
print("Content image filename :", CONTENT_IMAGE_FN)
# Out:
# Content image filename : nature.jpg

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
img = plt.imread(CONTENT_IMAGE_FN)
plt.axis('off')
plt.title('Content image')
plt.imshow(img)

# %% [markdown]
# # Style Image
#
# Run the below cell to upload the Style Image. Make sure to select **just 1 image**

# %%
style_img = files.upload()
# Out:
#      <input type="file" id="files-34f5a644-0f1a-4249-b8c9-271239193de8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34f5a644-0f1a-4249-b8c9-271239193de8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving styleq.jfif to styleq.jfif

# %%
STYLE_IMAGE_FN = list(style_img)[0]
STYLE_IMAGE_FN_temp = STYLE_IMAGE_FN.strip().replace(" ", "_")

if STYLE_IMAGE_FN != STYLE_IMAGE_FN_temp:
  os.rename(STYLE_IMAGE_FN, STYLE_IMAGE_FN_temp)
  STYLE_IMAGE_FN = STYLE_IMAGE_FN_temp

print("Style image filename :", STYLE_IMAGE_FN)
# Out:
# Style image filename : styleq.jfif

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(STYLE_IMAGE_FN)
plt.axis('off')
plt.title('Style image')
plt.imshow(img)

# %% [markdown]
# # Generate Image
#
# Run the below cells to generate the image

# %%
import os

RESULT_DIR = "generated/"
RESULT_PREFIX = RESULT_DIR + "gen"
FINAL_IMAGE_PATH = RESULT_PREFIX + "_at_iteration_%d.png" % (NUM_ITERATIONS)

if not os.path.exists(RESULT_DIR):
  os.makedirs(RESULT_DIR)

# %%
# !python {dir_path}/{NETWORK} {CONTENT_IMAGE_FN} {STYLE_IMAGE_FN} {RESULT_PREFIX} \
  --image_size {IMAGE_SIZE} --content_weight {CONTENT_WEIGHT} --style_weight \
  {STYLE_WEIGHT} --style_scale {STYLE_SCALE} --total_variation_weight \
  {TOTAL_VARIATION_WEIGHT} --content_loss_type {CONTENT_LOSS_TYPE} --num_iter \
  {NUM_ITERATIONS} --model {MODEL} --rescale_image {RESCALE_IMAGE} \
  --maintain_aspect_ratio {MAINTAIN_ASPECT_RATIO} --content_layer {CONTENT_LAYER} \
  --init_image {INITIALIZATION_IMAGE} --pool_type {POOLING_TYPE} --preserve_color \
  {PRESERVE_COLOR} --min_improvement {MIN_IMPROVEMENT}
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2021-11-20 10:51:53.466250: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-11-20 10:51:53.494292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 10:51:53.495146: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-11-20 10:51:53.495462: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-20 10:51:53.497268: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-11-20 10:51:53.498305: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-11-20 10:51:53.498647: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-11-20 10:51:53.500370: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-11-20 10:51:53.501741: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-11-20 10:51:53.505905: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-11-20 10:51:53.506020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 10:51:53.506869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 10:51:53.507613: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-11-20 10:51:53.513244: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2021-11-20 10:51:53.513507: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557b96a7d180 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-11-20 10:51:53.513543: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-11-20 10:51:53.618199: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 10:51:53.619253: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557b96a7d340 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-11-20 10:51:53.619295: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2021-11-20 10:51:53.619516: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 10:51:53.620444: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-11-20 10:51:53.620875: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-20 10:51:53.620934: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-11-20 10:51:53.620980: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-11-20 10:51:53.621021: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-11-20 10:51:53.622114: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-11-20 10:51:53.622212: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-11-20 10:51:53.622290: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-11-20 10:51:53.622472: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 10:51:53.623789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 10:51:53.624993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-11-20 10:51:53.625076: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-20 10:51:53.627042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-20 10:51:53.627087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-11-20 10:51:53.627112: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-11-20 10:51:53.627386: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 10:51:53.628728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 10:51:53.629941: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-11-20 10:51:53.630004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Model loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Starting iteration 1 of 50
# 2021-11-20 10:51:59.145725: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-11-20 10:51:59.298495: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Current loss value: 400634270.0  Improvement : 0.000 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_1.png
# Iteration 1 completed in 31s
# Starting iteration 2 of 50
# Current loss value: 134998340.0  Improvement : 66.304 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_2.png
# Iteration 2 completed in 24s
# Starting iteration 3 of 50
# Current loss value: 80220424.0  Improvement : 40.577 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_3.png
# Iteration 3 completed in 24s
# Starting iteration 4 of 50
# Current loss value: 62755656.0  Improvement : 21.771 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_4.png
# Iteration 4 completed in 24s
# Starting iteration 5 of 50
# Current loss value: 52653624.0  Improvement : 16.097 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_5.png
# Iteration 5 completed in 24s
# Starting iteration 6 of 50
# Current loss value: 46042470.0  Improvement : 12.556 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_6.png
# Iteration 6 completed in 24s
# Starting iteration 7 of 50
# Current loss value: 41911940.0  Improvement : 8.971 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_7.png
# Iteration 7 completed in 24s
# Starting iteration 8 of 50
# Current loss value: 38447252.0  Improvement : 8.267 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_8.png
# Iteration 8 completed in 24s
# Starting iteration 9 of 50
# Current loss value: 36078996.0  Improvement : 6.160 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_9.png
# Iteration 9 completed in 24s
# Starting iteration 10 of 50
# Current loss value: 34096908.0  Improvement : 5.494 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_10.png
# Iteration 10 completed in 24s
# Starting iteration 11 of 50
# Current loss value: 32668306.0  Improvement : 4.190 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_11.png
# Iteration 11 completed in 24s
# Starting iteration 12 of 50
# Current loss value: 31290878.0  Improvement : 4.216 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_12.png
# Iteration 12 completed in 24s
# Starting iteration 13 of 50
# Current loss value: 30063208.0  Improvement : 3.923 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_13.png
# Iteration 13 completed in 24s
# Starting iteration 14 of 50
# Current loss value: 28865832.0  Improvement : 3.983 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_14.png
# Iteration 14 completed in 24s
# Starting iteration 15 of 50
# Current loss value: 27956932.0  Improvement : 3.149 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_15.png
# Iteration 15 completed in 24s
# Starting iteration 16 of 50
# Current loss value: 27187248.0  Improvement : 2.753 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_16.png
# Iteration 16 completed in 24s
# Starting iteration 17 of 50
# Current loss value: 26416490.0  Improvement : 2.835 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_17.png
# Iteration 17 completed in 24s
# Starting iteration 18 of 50
# Current loss value: 25821040.0  Improvement : 2.254 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_18.png
# Iteration 18 completed in 24s
# Starting iteration 19 of 50
# Current loss value: 25327194.0  Improvement : 1.913 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_19.png
# Iteration 19 completed in 24s
# Starting iteration 20 of 50
# Current loss value: 24809284.0  Improvement : 2.045 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_20.png
# Iteration 20 completed in 24s
# Starting iteration 21 of 50
# Current loss value: 24303630.0  Improvement : 2.038 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_21.png
# Iteration 21 completed in 24s
# Starting iteration 22 of 50
# Current loss value: 23849028.0  Improvement : 1.871 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_22.png
# Iteration 22 completed in 24s
# Starting iteration 23 of 50
# Current loss value: 23423358.0  Improvement : 1.785 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_23.png
# Iteration 23 completed in 24s
# Starting iteration 24 of 50
# Current loss value: 23074652.0  Improvement : 1.489 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_24.png
# Iteration 24 completed in 24s
# Starting iteration 25 of 50
# Current loss value: 22754862.0  Improvement : 1.386 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_25.png
# Iteration 25 completed in 24s
# Starting iteration 26 of 50
# Current loss value: 22419838.0  Improvement : 1.472 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_26.png
# Iteration 26 completed in 25s
# Starting iteration 27 of 50
# Current loss value: 22096650.0  Improvement : 1.442 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_27.png
# Iteration 27 completed in 24s
# Starting iteration 28 of 50
# Current loss value: 21758830.0  Improvement : 1.529 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_28.png
# Iteration 28 completed in 24s
# Starting iteration 29 of 50
# Current loss value: 21490808.0  Improvement : 1.232 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_29.png
# Iteration 29 completed in 24s
# Starting iteration 30 of 50
# Current loss value: 21191860.0  Improvement : 1.391 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_30.png
# Iteration 30 completed in 24s
# Starting iteration 31 of 50
# Current loss value: 20923284.0  Improvement : 1.267 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_31.png
# Iteration 31 completed in 24s
# Starting iteration 32 of 50
# Current loss value: 20558344.0  Improvement : 1.744 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_32.png
# Iteration 32 completed in 24s
# Starting iteration 33 of 50
# Current loss value: 20184914.0  Improvement : 1.816 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_33.png
# Iteration 33 completed in 24s
# Starting iteration 34 of 50
# Current loss value: 19911918.0  Improvement : 1.352 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_34.png
# Iteration 34 completed in 24s
# Starting iteration 35 of 50
# Current loss value: 19660674.0  Improvement : 1.262 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_35.png
# Iteration 35 completed in 24s
# Starting iteration 36 of 50
# Current loss value: 19445882.0  Improvement : 1.092 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_36.png
# Iteration 36 completed in 24s
# Starting iteration 37 of 50
# Current loss value: 19239208.0  Improvement : 1.063 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_37.png
# Iteration 37 completed in 24s
# Starting iteration 38 of 50
# Current loss value: 19056834.0  Improvement : 0.948 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_38.png
# Iteration 38 completed in 24s
# Starting iteration 39 of 50
# Current loss value: 18867758.0  Improvement : 0.992 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_39.png
# Iteration 39 completed in 24s
# Starting iteration 40 of 50
# Current loss value: 18698244.0  Improvement : 0.898 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_40.png
# Iteration 40 completed in 24s
# Starting iteration 41 of 50
# Current loss value: 18565852.0  Improvement : 0.708 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_41.png
# Iteration 41 completed in 24s
# Starting iteration 42 of 50
# Current loss value: 18391132.0  Improvement : 0.941 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_42.png
# Iteration 42 completed in 24s
# Starting iteration 43 of 50
# Current loss value: 18238390.0  Improvement : 0.831 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_43.png
# Iteration 43 completed in 24s
# Starting iteration 44 of 50
# Current loss value: 18073888.0  Improvement : 0.902 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_44.png
# Iteration 44 completed in 24s
# Starting iteration 45 of 50
# Current loss value: 17932160.0  Improvement : 0.784 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_45.png
# Iteration 45 completed in 24s
# Starting iteration 46 of 50
# Current loss value: 17806298.0  Improvement : 0.702 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_46.png
# Iteration 46 completed in 24s
# Starting iteration 47 of 50
# Current loss value: 17667610.0  Improvement : 0.779 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_47.png
# Iteration 47 completed in 24s
# Starting iteration 48 of 50
# Current loss value: 17554686.0  Improvement : 0.639 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_48.png
# Iteration 48 completed in 24s
# Starting iteration 49 of 50
# Current loss value: 17435568.0  Improvement : 0.679 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_49.png
# Iteration 49 completed in 24s
# Starting iteration 50 of 50
# Current loss value: 17290306.0  Improvement : 0.833 %
# Rescaling Image to (500, 796)
# Image saved as generated/gen_at_iteration_50.png
# Iteration 50 completed in 24s

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Generated image')
plt.imshow(img)

# %% [markdown]
# # (Optional) Color Transfer
#
# If you wish for color transfer between the content image and the generated image, then run the next cell, else skip to "Download Generated Image" section

# %%
COLOR_TRANSFER = 'color_transfer.py'
COLOR_FINAL_IMAGE_PATH = FINAL_IMAGE_PATH[:-4] + '_%s_color.png'

# Optional - Use Histogram matching (0 for no, 1 for yes)
HISTOGRAM_MATCH = 0

if HISTOGRAM_MATCH == 0:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('original')
else:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('histogram')
  

# !python {dir_path}/{COLOR_TRANSFER} {CONTENT_IMAGE_FN} {FINAL_IMAGE_PATH} --hist_match {HISTOGRAM_MATCH}
# Out:
# Neural-Style-Transfer/color_transfer.py:116: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   generated_image = imread(args.generated_image, mode="RGB")
# Neural-Style-Transfer/color_transfer.py:119: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   content_image = imread(args.content_image, mode=mode)
# Neural-Style-Transfer/color_transfer.py:120: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   content_image = imresize(content_image, (img_width, img_height), interp='bicubic')
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:129: DeprecationWarning:     `imsave` is deprecated!
#     `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imwrite`` instead.
#   imsave(image_path, img)
# Image saved at path : generated/gen_at_iteration_50_original_color.png

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(COLOR_FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Color Transferred Generated image')
plt.imshow(img)

# %% [markdown]
# # Download Color Transfered Image
#
# Run the following cell to download the color transferred result

# %%
# download the color transfered image
files.download(COLOR_FINAL_IMAGE_PATH)

# %% [markdown]
# # Download Generated Image
#
# Run the following cell to download the final result

# %%
files.download(FINAL_IMAGE_PATH)
